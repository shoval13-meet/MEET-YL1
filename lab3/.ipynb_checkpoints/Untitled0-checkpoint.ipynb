# %%
import csv

s = open('cigarettes.csv', 'rb')
reader = csv.reader(s)
rawnum = 0
item1 = []
item2 = []

for row in reader:
    if index != 0:
        r = row[0].split()
        m = map(float, r[1:])
        item1.append(m[0])
        item2.append(m[1])
        
    index += 1
print(item1,item2)
s.close()
# Out:
# ([14.1, 16.0, 29.8, 8.0, 4.1, 15.0, 8.8, 12.4, 16.6, 14.9, 13.7, 15.1, 7.8, 11.4, 9.0, 1.0, 17.0, 12.8, 15.8, 4.5, 14.5, 7.3, 8.6, 15.2, 12.0], [0.86, 1.06, 2.03, 0.67, 0.4, 1.04, 0.76, 0.95, 1.12, 1.02, 1.01, 0.9, 0.57, 0.78, 0.74, 0.13, 1.26, 1.08, 0.96, 0.42, 1.01, 0.61, 0.69, 1.02, 0.82])

# %%
from pylab import*

fig = plt.figure()
ax = fig.add_subplot(111)
ax.set_title("cigarettes content")
ax.set_xlable("tar content")
ax.set_ylable("nicotine content")

savefig(cig_scatter.png)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-34-1c6061dc67ef> in <module>()
#       4 ax = fig.add_subplot(111)
#       5 ax.set_title("cigarettes content")
# ----> 6 ax.set_xlable("tar content")
#       7 ax.set_ylable("nicotine content")
#       8
#
# AttributeError: 'AxesSubplot' object has no attribute 'set_xlable'

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.set_title("cigarettes content")
ax.set_xlabel("tar content")
ax.set_ylabel("nicotine content")
scatter(item1,item2)
savefig("cig_scatter.png")
